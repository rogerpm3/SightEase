# %% [markdown]
# ## Install ultralytics

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random
import os
import cv2
import shutil
import tqdm

# %%
# Check GPU is working or not
import torch
print(f"Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Using torch 2.2.1+cu121 (NVIDIA GeForce RTX 4060 Laptop GPU)

# %%
images_path = 'C:/Users/roger/Desktop/Social/archive1/colorful_fashion_dataset_for_object_detection/JPEGImages/'
annotations_path  = 'C:/Users/roger/Desktop/Social/archive1/colorful_fashion_dataset_for_object_detection/Annotations_txt/'
path = 'C:/Users/roger/Desktop/Social/archive1/colorful_fashion_dataset_for_object_detection/'

# %%
from ultralytics import YOLO

# load pre-trained model
detection_model = YOLO("yolov8m.pt")

# %% [markdown]
# # Prepare Dataset

# %%
train = []
with open(path+'ImageSets/Main/trainval.txt', 'r') as f:
    for line in f.readlines():
        if line[-1]=='\n':
            line = line[:-1]
        train.append(line)

test = []
with open(path+'ImageSets/Main/test.txt', 'r') as f:
    for line in f.readlines():
        if line[-1]=='\n':
            line = line[:-1]
        test.append(line)

# %%
len(train), len(test)
# Out:
# (2145, 537)

# %%
train_path = 'C:/Users/roger/Desktop/Social/train/'
test_path = 'C:/Users/roger/Desktop/Social/test/'

print('Copying Train Data..!!')
for i in tqdm.tqdm(train):
    a = shutil.copyfile(images_path+i+'.jpg', train_path+'images/'+i+'.jpg')
    a = shutil.copyfile(annotations_path+i+'.txt', train_path+'labels/'+i+'.txt')

print('Copying Test Data..!!')
for i in tqdm.tqdm(test):
    a = shutil.copyfile(images_path+i+'.jpg', test_path+'images/'+i+'.jpg')
    a = shutil.copyfile(annotations_path+i+'.txt', test_path+'labels/'+i+'.txt')
# Out:
# Copying Train Data..!!
# 100%|██████████| 2145/2145 [00:03<00:00, 620.30it/s]
# Copying Test Data..!!
# 100%|██████████| 537/537 [00:00<00:00, 694.65it/s]

# %% [markdown]
# # Train Custom Model

# %%
model = YOLO("yolov8m.pt")

model.train(data='data.yaml', epochs=30)
# Out:
# New https://pypi.org/project/ultralytics/8.1.34 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.24 🚀 Python-3.11.8 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
# %matplotlib inline
model_path = 'runs/detect/train3/'

def plot(ls, size):
    c=1
    plt.figure(figsize=(15,10))
    for im in ls:
        plt.subplot(size[0],size[1],c)
        im = plt.imread(model_path+im)
        plt.imshow(im)
        c+=1
    plt.show()

plot(['P_curve.png','R_curve.png'], (1,2))
plot(['F1_curve.png','PR_curve.png'], (1,2))
plot(['confusion_matrix.png','labels.jpg'], (1,2))
plot(['results.png'],(1,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11         c+=1
#      12     plt.show()
# ---> 14 plot(['P_curve.png','R_curve.png'], (1,2))
#      15 plot(['F1_curve.png','PR_curve.png'], (1,2))
#      16 plot(['confusion_matrix.png','labels.jpg'], (1,2))
#
# Cell In[1], line 6, in plot(ls, size)
#       4 def plot(ls, size):
#       5     c=1
# ----> 6     plt.figure(figsize=(15,10))
#       7     for im in ls:
#       8         plt.subplot(size[0],size[1],c)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Test Model

# %%
# choose random image from dataset
plt.figure(figsize=(20,20))
imgs = random.sample(os.listdir(images_path), 6)
c=1
for i,img in enumerate(imgs):
    i=i+2
    image=model.predict(source=images_path+img, conf=0.4, save=True, line_thickness=2)
    if i!=0:
        im = plt.imread("runs/detect/train3"+str(i)+"/"+img)
    else:
        im = plt.imread("runs/detect/train3/"+img)

    plt.subplot(2,3,c)
    plt.axis('off')
    plt.imshow(im)
    c+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 for i,img in enumerate(imgs):
#       6     i=i+2
# ----> 7     image=model.predict(source=images_path+img, conf=0.4, save=True, line_thickness=2)
#       8     if i!=0:
#       9         im = plt.imread("runs/detect/train3"+str(i)+"/"+img)
#
# NameError: name 'model' is not defined

# %%
plt.figure(figsize=(20,20))
imgs = random.sample(os.listdir(images_path), 6)

image=model.predict(source="C:/Users/roger/Pictures/Screenshots/Screenshot 2024-03-25 122846.png", conf=0.4, save=True, line_thickness=2)
im = plt.imread("runs/detect/train26/Screenshot 2024-03-25 122846.png")
plt.subplot(2,3,1)
plt.axis('off')
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure(figsize=(20,20))
# ----> 2 imgs = random.sample(os.listdir(images_path), 6)
#       4 image=model.predict(source="C:/Users/roger/Pictures/Screenshots/Screenshot 2024-03-25 122846.png", conf=0.4, save=True, line_thickness=2)
#       5 im = plt.imread("runs/detect/train26/Screenshot 2024-03-25 122846.png")
#
# NameError: name 'images_path' is not defined

# %%
import cv2

vid = cv2.VideoCapture(0)
vid.set(3,200)
vid.set(4,200)

while(True):
    #inside infinity loop
    ret, frame = vid.read()
    
    cv2.imshow('frame', frame)
    print(ret)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


vid.release()
# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
